# %% [markdown]
# ## Making Circuit in Qiskit and Running it on Quantinuum Backend

# %% [markdown]
# Making use of `qiskit_quantinuum`

# %%
from qiskit_quantinuum import Quantinuum

# %% [markdown]
# See all the backends associated:

# %%
Quantinuum.save_account(user_name="monitsharma@smu.edu.sg")
Quantinuum.load_account()

# %%
Quantinuum.backends()
# Out:
# [<QuantinuumBackend('H1-1SC')>,
#  <QuantinuumBackend('H1-1E')>,
#  <QuantinuumBackend('H1-1')>]

# %% [markdown]
# Select a device:

# %%
device = 'H1-1E'
backend = Quantinuum.get_backend(device)
status = backend.status()

print(device, "status :", status.status_msg)
# Out:
# H1-1E status : online

# %% [markdown]
# ## Bell Pair

# %%
import numpy as np

from qiskit import QuantumCircuit, execute

from qiskit.visualization import plot_histogram

# %%
n_qubits = 2
circuit = QuantumCircuit(n_qubits, n_qubits, name='Bell Test')
circuit.h(0)
circuit.cx(0, 1)
circuit.measure_all()

circuit.draw('mpl',style="iqp")

# %%
shots = 100
job = execute(circuit, backend, shots=shots)

# %%
job.status()
# Out:
# ---------------------------------------------------------------------------
# CancelledError                            Traceback (most recent call last)
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\asyncio\tasks.py:234, in Task.__step(***failed resolving arguments***)
#     233     else:
# --> 234         result = coro.throw(exc)
#     235 except StopIteration as exc:
#
# File c:\Users\monitsharma\Downloads\code\quantinuum\.venv\lib\site-packages\websockets\legacy\protocol.py:552, in WebSocketCommonProtocol.recv(self)
#     549 try:
#     550     # If asyncio.wait() is canceled, it doesn't cancel
#     551     # pop_message_waiter and self.transfer_data_task.
# --> 552     await asyncio.wait(
#     553         [pop_message_waiter, self.transfer_data_task],
#     554         return_when=asyncio.FIRST_COMPLETED,
#     555     )
#     556 finally:
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\asyncio\tasks.py:384, in wait(fs, timeout, return_when)
#     382 fs = {ensure_future(f, loop=loop) for f in fs}
# --> 384 return await _wait(fs, timeout, return_when, loop)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\asyncio\tasks.py:491, in _wait(fs, timeout, return_when, loop)
#     490 try:
# --> 491     await waiter
#     492 finally:
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\asyncio\futures.py:285, in Future.__await__(self)
#     284     self._asyncio_future_blocking = True
# --> 285     yield self  # This tells Task to wait for completion.
#     286 if not self.done():
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\asyncio\tasks.py:304, in Task.__wakeup(self, future)
#     303 try:
# --> 304     future.result()
#     305 except BaseException as exc:
#     306     # This may also be a cancellation.
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\asyncio\futures.py:196, in Future.result(self)
#     195     exc = self._make_cancelled_error()
# --> 196     raise exc
#     197 if self._state != _FINISHED:
#
# CancelledError:
#
# During handling of the above exception, another exception occurred:
#
# CancelledError                            Traceback (most recent call last)
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\asyncio\tasks.py:456, in wait_for(fut, timeout)
#     455 try:
# --> 456     return fut.result()
#     457 except exceptions.CancelledError as exc:
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\asyncio\futures.py:196, in Future.result(self)
#     195     exc = self._make_cancelled_error()
# --> 196     raise exc
#     197 if self._state != _FINISHED:
#
# CancelledError:
#
# The above exception was the direct cause of the following exception:
#
# TimeoutError                              Traceback (most recent call last)
# File c:\Users\monitsharma\Downloads\code\quantinuum\experiments\qiskit_quantinuum\quantinuumjob.py:274, in QuantinuumJob._get_status(self, job_id, timeout)
#     273 await websocket.send(json.dumps(body))
# --> 274 api_response = await asyncio.wait_for(websocket.recv(), timeout=timeout)
#     275 api_response = json.loads(api_response)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\asyncio\tasks.py:458, in wait_for(fut, timeout)
#     457         except exceptions.CancelledError as exc:
# --> 458             raise exceptions.TimeoutError() from exc
#     459 finally:
#
# TimeoutError:
#
# During handling of the above exception, another exception occurred:
#
# JobError                                  Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 job.status()
#
# File c:\Users\monitsharma\Downloads\code\quantinuum\experiments\qiskit_quantinuum\quantinuumjob.py:309, in QuantinuumJob.status(self, timeout)
#     306 # Wait for results sequentially
#     307 for job_id in self._job_ids:
#     308     self._experiment_results.append(
# --> 309         asyncio.get_event_loop().run_until_complete(self._get_status(job_id, timeout))
#     310         )
#     312 # Process results
#     313 self._result = self._process_results()
#
# File c:\Users\monitsharma\Downloads\code\quantinuum\.venv\lib\site-packages\nest_asyncio.py:98, in _patch_loop.<locals>.run_until_complete(self, future)
#      95 if not f.done():
#      96     raise RuntimeError(
#      97         'Event loop stopped before Future completed.')
# ---> 98 return f.result()
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\asyncio\futures.py:201, in Future.result(self)
#     199 self.__log_traceback = False
#     200 if self._exception is not None:
# --> 201     raise self._exception.with_traceback(self._exception_tb)
#     202 return self._result
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\asyncio\tasks.py:232, in Task.__step(***failed resolving arguments***)
#     228 try:
#     229     if exc is None:
#     230         # We use the `send` method directly, because coroutines
#     231         # don't have `__iter__` and `__next__` methods.
# --> 232         result = coro.send(None)
#     233     else:
#     234         result = coro.throw(exc)
#
# File c:\Users\monitsharma\Downloads\code\quantinuum\experiments\qiskit_quantinuum\quantinuumjob.py:292, in QuantinuumJob._get_status(self, job_id, timeout)
#     290             request_delay = min(min(request_delay*1.5, 10), residual_delay)
#     291 except Exception as err:
# --> 292     raise JobError(str(err))
#     294 return api_response
#
# JobError: ''

# %%
result = job.result()

print("Job ID:", result.job_id)
print("Job success:", result.success)
# Out:
# ---------------------------------------------------------------------------
# CancelledError                            Traceback (most recent call last)
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\asyncio\tasks.py:234, in Task.__step(***failed resolving arguments***)
#     233     else:
# --> 234         result = coro.throw(exc)
#     235 except StopIteration as exc:
#
# File c:\Users\monitsharma\Downloads\code\quantinuum\.venv\lib\site-packages\websockets\legacy\protocol.py:552, in WebSocketCommonProtocol.recv(self)
#     549 try:
#     550     # If asyncio.wait() is canceled, it doesn't cancel
#     551     # pop_message_waiter and self.transfer_data_task.
# --> 552     await asyncio.wait(
#     553         [pop_message_waiter, self.transfer_data_task],
#     554         return_when=asyncio.FIRST_COMPLETED,
#     555     )
#     556 finally:
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\asyncio\tasks.py:384, in wait(fs, timeout, return_when)
#     382 fs = {ensure_future(f, loop=loop) for f in fs}
# --> 384 return await _wait(fs, timeout, return_when, loop)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\asyncio\tasks.py:491, in _wait(fs, timeout, return_when, loop)
#     490 try:
# --> 491     await waiter
#     492 finally:
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\asyncio\futures.py:285, in Future.__await__(self)
#     284     self._asyncio_future_blocking = True
# --> 285     yield self  # This tells Task to wait for completion.
#     286 if not self.done():
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\asyncio\tasks.py:304, in Task.__wakeup(self, future)
#     303 try:
# --> 304     future.result()
#     305 except BaseException as exc:
#     306     # This may also be a cancellation.
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\asyncio\futures.py:196, in Future.result(self)
#     195     exc = self._make_cancelled_error()
# --> 196     raise exc
#     197 if self._state != _FINISHED:
#
# CancelledError:
#
# During handling of the above exception, another exception occurred:
#
# CancelledError                            Traceback (most recent call last)
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\asyncio\tasks.py:456, in wait_for(fut, timeout)
#     455 try:
# --> 456     return fut.result()
#     457 except exceptions.CancelledError as exc:
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\asyncio\futures.py:196, in Future.result(self)
#     195     exc = self._make_cancelled_error()
# --> 196     raise exc
#     197 if self._state != _FINISHED:
#
# CancelledError:
#
# The above exception was the direct cause of the following exception:
#
# TimeoutError                              Traceback (most recent call last)
# File c:\Users\monitsharma\Downloads\code\quantinuum\experiments\qiskit_quantinuum\quantinuumjob.py:274, in QuantinuumJob._get_status(self, job_id, timeout)
#     273 await websocket.send(json.dumps(body))
# --> 274 api_response = await asyncio.wait_for(websocket.recv(), timeout=timeout)
#     275 api_response = json.loads(api_response)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\asyncio\tasks.py:458, in wait_for(fut, timeout)
#     457         except exceptions.CancelledError as exc:
# --> 458             raise exceptions.TimeoutError() from exc
#     459 finally:
#
# TimeoutError:
#
# During handling of the above exception, another exception occurred:
#
# JobError                                  Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 result = job.result()
#       3 print("Job ID:", result.job_id)
#       4 print("Job success:", result.success)
#
# File c:\Users\monitsharma\Downloads\code\quantinuum\experiments\qiskit_quantinuum\quantinuumjob.py:225, in QuantinuumJob.result(self, timeout)
#     222 # Wait for results sequentially
#     223 for job_id in self._job_ids:
#     224     self._experiment_results.append(
# --> 225         asyncio.get_event_loop().run_until_complete(self._get_status(job_id, timeout))
#     226         )
#     228 # Process results
#     229 self._result = self._process_results()
#
# File c:\Users\monitsharma\Downloads\code\quantinuum\.venv\lib\site-packages\nest_asyncio.py:98, in _patch_loop.<locals>.run_until_complete(self, future)
#      95 if not f.done():
#      96     raise RuntimeError(
#      97         'Event loop stopped before Future completed.')
# ---> 98 return f.result()
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\asyncio\futures.py:201, in Future.result(self)
#     199 self.__log_traceback = False
#     200 if self._exception is not None:
# --> 201     raise self._exception.with_traceback(self._exception_tb)
#     202 return self._result
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\asyncio\tasks.py:232, in Task.__step(***failed resolving arguments***)
#     228 try:
#     229     if exc is None:
#     230         # We use the `send` method directly, because coroutines
#     231         # don't have `__iter__` and `__next__` methods.
# --> 232         result = coro.send(None)
#     233     else:
#     234         result = coro.throw(exc)
#
# File c:\Users\monitsharma\Downloads\code\quantinuum\experiments\qiskit_quantinuum\quantinuumjob.py:292, in QuantinuumJob._get_status(self, job_id, timeout)
#     290             request_delay = min(min(request_delay*1.5, 10), residual_delay)
#     291 except Exception as err:
# --> 292     raise JobError(str(err))
#     294 return api_response
#
# JobError: ''
