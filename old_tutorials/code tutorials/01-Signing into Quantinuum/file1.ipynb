# %% [markdown]
# # How to submit to Quantinuum H-series Devices?

# %%
import pytket
import pytket.extensions.quantinuum


print("pytket version: ", pytket.__version__)
print("pytket-extensions-quantinuum version: ", pytket.extensions.quantinuum.__extension_version__)
# Out:
# pytket version:  1.25.0
# pytket-extensions-quantinuum version:  0.30.0

# %% [markdown]
# ## Circuit Preparation

# %%
from pytket.circuit import Circuit, fresh_symbol
from pytket.circuit.display import render_circuit_jupyter


# set up a bell test
circuit = Circuit(2, name="Bell State Test")
circuit.H(0) # Hadamard gate
circuit.CX(0, 1) # CNOT gate
circuit.measure_all() # measure all qubits

# render the circuit
render_circuit_jupyter(circuit)
# Out:
# <div style="resize: vertical; overflow: auto; height: 400px; display: block">
#     <iframe srcdoc="
# &lt;!DOCTYPE html&gt;
# &lt;html lang=&#34;en&#34;&gt;
# &lt;head&gt;
#     &lt;meta charset=&#34;UTF-8&#34;&gt;
#     &lt;!-- Download Vue 3--&gt;
# &lt;script type=&#34;application/javascript&#34; src=&#34;https://cdn.jsdelivr.net/npm/vue@3&#34;&gt;&lt;/script&gt;
# &lt;!-- Download Circuit Renderer with styles --&gt;
# &lt;script type=&#34;application/javascript&#34; src=&#34;https://unpkg.com/pytket-circuit-renderer@0.7/dist/pytket-circuit-renderer.umd.js&#34;&gt;&lt;/script&gt;
# &lt;link rel=&#34;stylesheet&#34; href=&#34;https://unpkg.com/pytket-circuit-renderer@0.7/dist/pytket-circuit-renderer.css&#34;&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#
#     &lt;div id=&#34;circuit-display-vue-container-9a3f74b7-8431-4d15-b38f-bf3cbc1b6462&#34; class=&#34;pytket-circuit-display-container&#34;&gt;
#         &lt;div style=&#34;display: none&#34;&gt;
#             &lt;div id=&#34;circuit-json-to-display&#34;&gt;{&#34;bits&#34;: [[&#34;c&#34;, [0]], [&#34;c&#34;, [1]]], &#34;commands&#34;: [{&#34;args&#34;: [[&#34;q&#34;, [0]]], &#34;op&#34;: {&#34;type&#34;: &#34;H&#34;}}, {&#34;args&#34;: [[&#34;q&#34;, [0]], [&#34;q&#34;, [1]]], &#34;op&#34;: {&#34;type&#34;: &#34;CX&#34;}}, {&#34;args&#34;: [[&#34;q&#34;, [0]], [&#34;c&#34;, [0]]], &#34;op&#34;: {&#34;type&#34;: &#34;Measure&#34;}}, {&#34;args&#34;: [[&#34;q&#34;, [1]], [&#34;c&#34;, [1]]], &#34;op&#34;: {&#34;type&#34;: &#34;Measure&#34;}}], &#34;created_qubits&#34;: [], &#34;discarded_qubits&#34;: [], &#34;implicit_permutation&#34;: [[[&#34;q&#34;, [0]], [&#34;q&#34;, [0]]], [[&#34;q&#34;, [1]], [&#34;q&#34;, [1]]]], &#34;name&#34;: &#34;Bell State Test&#34;, &#34;phase&#34;: &#34;0.0&#34;, &#34;qubits&#34;: [[&#34;q&#34;, [0]], [&#34;q&#34;, [1]]]}&lt;/div&gt;
#         &lt;/div&gt;
#         &lt;circuit-display-container
#                 :circuit-element-str=&#34;&#39;#circuit-json-to-display&#39;&#34;
#                 :init-render-options=&#34;initRenderOptions&#34;
#         &gt;&lt;/circuit-display-container&gt;
#     &lt;/div&gt;
#     &lt;script type=&#34;application/javascript&#34;&gt;
#       const circuitRendererUid = &#34;9a3f74b7-8431-4d15-b38f-bf3cbc1b6462&#34;;
#       const displayOptions = JSON.parse(&#39;{}&#39;);
#
#       // Script to initialise the circuit renderer app
#
# const { createApp } = Vue;
# const circuitDisplayContainer = window[&#34;pytket-circuit-renderer&#34;].default;
# // Init variables to be shared between circuit display instances
# if (typeof window.pytketCircuitDisplays === &#34;undefined&#34;) {
#     window.pytketCircuitDisplays = {};
# }
# // Create the root Vue component
# const app = createApp({
#     delimiters: [&#39;[[#&#39;, &#39;#]]&#39;],
#     components: { circuitDisplayContainer },
#     data () {
#       return {
#         initRenderOptions: displayOptions,
#       }
#     }
# })
# app.config.unwrapInjectedRef = true;
# app.mount(&#34;#circuit-display-vue-container-&#34;+circuitRendererUid);
# window.pytketCircuitDisplays[circuitRendererUid] = app;
#     &lt;/script&gt;
#
#
#
# &lt;/body&gt;
# &lt;/html&gt;
# "
#             width="100%" height="100%"
#             style="border: none; outline: none; overflow: auto"></iframe>
# </div>

# %% [markdown]
# ## Select Device

# %%
from pytket.extensions.quantinuum import QuantinuumBackend

machine = 'H1-1E'

backend = QuantinuumBackend(device_name= machine)
backend.login()

# %% [markdown]
# Get the status of the machine

# %%
print(machine, "status: ", QuantinuumBackend.device_state(device_name=machine))
# Out:
# H1-1E status:  online

# %% [markdown]
# ## Circuit Compilation

# %%
compiled_circuit = backend.get_compiled_circuit(circuit,optimisation_level=2)
render_circuit_jupyter(compiled_circuit)
# Out:
# <div style="resize: vertical; overflow: auto; height: 400px; display: block">
#     <iframe srcdoc="
# &lt;!DOCTYPE html&gt;
# &lt;html lang=&#34;en&#34;&gt;
# &lt;head&gt;
#     &lt;meta charset=&#34;UTF-8&#34;&gt;
#     &lt;!-- Download Vue 3--&gt;
# &lt;script type=&#34;application/javascript&#34; src=&#34;https://cdn.jsdelivr.net/npm/vue@3&#34;&gt;&lt;/script&gt;
# &lt;!-- Download Circuit Renderer with styles --&gt;
# &lt;script type=&#34;application/javascript&#34; src=&#34;https://unpkg.com/pytket-circuit-renderer@0.7/dist/pytket-circuit-renderer.umd.js&#34;&gt;&lt;/script&gt;
# &lt;link rel=&#34;stylesheet&#34; href=&#34;https://unpkg.com/pytket-circuit-renderer@0.7/dist/pytket-circuit-renderer.css&#34;&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#
#     &lt;div id=&#34;circuit-display-vue-container-b4bcb42a-c12a-42b2-afdf-3b0c510d363a&#34; class=&#34;pytket-circuit-display-container&#34;&gt;
#         &lt;div style=&#34;display: none&#34;&gt;
#             &lt;div id=&#34;circuit-json-to-display&#34;&gt;{&#34;bits&#34;: [[&#34;c&#34;, [0]], [&#34;c&#34;, [1]]], &#34;commands&#34;: [{&#34;args&#34;: [[&#34;q&#34;, [0]]], &#34;op&#34;: {&#34;params&#34;: [&#34;-0.5&#34;, &#34;-1.5&#34;], &#34;type&#34;: &#34;PhasedX&#34;}}, {&#34;args&#34;: [[&#34;q&#34;, [1]]], &#34;op&#34;: {&#34;params&#34;: [&#34;0.5&#34;, &#34;-1.5&#34;], &#34;type&#34;: &#34;PhasedX&#34;}}, {&#34;args&#34;: [[&#34;q&#34;, [0]], [&#34;q&#34;, [1]]], &#34;op&#34;: {&#34;params&#34;: [&#34;0.5&#34;], &#34;type&#34;: &#34;ZZPhase&#34;}}, {&#34;args&#34;: [[&#34;q&#34;, [0]], [&#34;c&#34;, [0]]], &#34;op&#34;: {&#34;type&#34;: &#34;Measure&#34;}}, {&#34;args&#34;: [[&#34;q&#34;, [1]]], &#34;op&#34;: {&#34;params&#34;: [&#34;1/2&#34;, &#34;0&#34;], &#34;type&#34;: &#34;PhasedX&#34;}}, {&#34;args&#34;: [[&#34;q&#34;, [1]], [&#34;c&#34;, [1]]], &#34;op&#34;: {&#34;type&#34;: &#34;Measure&#34;}}], &#34;created_qubits&#34;: [], &#34;discarded_qubits&#34;: [], &#34;implicit_permutation&#34;: [[[&#34;q&#34;, [0]], [&#34;q&#34;, [0]]], [[&#34;q&#34;, [1]], [&#34;q&#34;, [1]]]], &#34;name&#34;: &#34;Bell State Test&#34;, &#34;phase&#34;: &#34;1.75&#34;, &#34;qubits&#34;: [[&#34;q&#34;, [0]], [&#34;q&#34;, [1]]]}&lt;/div&gt;
#         &lt;/div&gt;
#         &lt;circuit-display-container
#                 :circuit-element-str=&#34;&#39;#circuit-json-to-display&#39;&#34;
#                 :init-render-options=&#34;initRenderOptions&#34;
#         &gt;&lt;/circuit-display-container&gt;
#     &lt;/div&gt;
#     &lt;script type=&#34;application/javascript&#34;&gt;
#       const circuitRendererUid = &#34;b4bcb42a-c12a-42b2-afdf-3b0c510d363a&#34;;
#       const displayOptions = JSON.parse(&#39;{}&#39;);
#
#       // Script to initialise the circuit renderer app
#
# const { createApp } = Vue;
# const circuitDisplayContainer = window[&#34;pytket-circuit-renderer&#34;].default;
# // Init variables to be shared between circuit display instances
# if (typeof window.pytketCircuitDisplays === &#34;undefined&#34;) {
#     window.pytketCircuitDisplays = {};
# }
# // Create the root Vue component
# const app = createApp({
#     delimiters: [&#39;[[#&#39;, &#39;#]]&#39;],
#     components: { circuitDisplayContainer },
#     data () {
#       return {
#         initRenderOptions: displayOptions,
#       }
#     }
# })
# app.config.unwrapInjectedRef = true;
# app.mount(&#34;#circuit-display-vue-container-&#34;+circuitRendererUid);
# window.pytketCircuitDisplays[circuitRendererUid] = app;
#     &lt;/script&gt;
#
#
#
# &lt;/body&gt;
# &lt;/html&gt;
# "
#             width="100%" height="100%"
#             style="border: none; outline: none; overflow: auto"></iframe>
# </div>

# %% [markdown]
# ## Circuit Cost

# %%
n_shots = 1000
backend.cost(compiled_circuit, n_shots=n_shots, syntax_checker='H1-1SC')
# Out:
# 11.6

# %% [markdown]
# ## Run the Circuit

# %%
handle = backend.process_circuit(compiled_circuit, n_shots=n_shots)
print(handle)
# Out:
# ('80c4c17a48544383b26f0ed43cb37901', 'null', 2, '[["c", 0], ["c", 1]]')

# %%
import json 
with open('pytket_example_job_handle.json','w') as file:
    json.dump(str(handle), file)

# %% [markdown]
# ## Check Job Status

# %%
status = backend.circuit_status(handle)
print(status)
# Out:
# CircuitStatus(status=<StatusEnum.COMPLETED: 'Circuit has completed. Results are ready.'>, message='{"name": "Bell State Test", "submit-date": "2024-03-08T09:54:22.566947", "result-date": "2024-03-08T09:54:25.713772", "queue-position": null, "cost": "11.6", "error": null}', error_detail=None, completed_time=None, queued_time=None, submitted_time=None, running_time=None, cancelled_time=None, error_time=None, queue_position=None)

# %% [markdown]
# ## Retrieve Results

# %%
from pytket.backends import ResultHandle

with open('pytket_example_job_handle.json', 'r') as file:
    handle_str = json.load(file)

handle = ResultHandle.from_str(handle_str)

# %%
result = backend.get_result(handle)

# %% [markdown]
# ## Save Results

# %%
import json 
with open('pytket_example.json','w') as file:
    json.dump(result.to_dict(), file)

# %%
from pytket.backends.backendresult import BackendResult
import json
with open('pytket_example.json') as file:
    data = json.load(file)

result = BackendResult.from_dict(data)

# %% [markdown]
# ## Analyze Results

# %%
print(result.get_counts())
print("-----------------------")
print(result.get_distribution())
# Out:
# Counter({(1, 1): 511, (0, 0): 487, (0, 1): 1, (1, 0): 1})
# -----------------------
# {(0, 0): 0.487, (0, 1): 0.001, (1, 0): 0.001, (1, 1): 0.511}

# %% [markdown]
# # Additional Features

# %% [markdown]
# ## Batch Submission

# %%
machine = 'H1-1E'

backend = QuantinuumBackend(device_name= machine)

print(machine, "status: ", QuantinuumBackend.device_state(device_name=machine))
# Out:
# H1-1E status:  online

# %%
machine = 'H1-1E'
n_shots = 1000

max_batch_cost = 1000

backend = QuantinuumBackend(device_name=machine)

# %%
batch1 = backend.start_batch(max_batch_cost=max_batch_cost, circuit= compiled_circuit, n_shots=n_shots)

# %% [markdown]
# Additional Jobs can be added to the batch using the `add_to_batch` function. The end of a batch can optionally be specified with `batch_end` flag

# %%
batch2 = backend.add_to_batch(batch1, compiled_circuit, n_shots=n_shots)
batch3 = backend.add_to_batch(batch1, compiled_circuit, n_shots=n_shots, batch_end=True)

# %% [markdown]
# The status for the batch jobs can be checked once submitted

# %%
handle_list = [batch1, batch2, batch3]

status_list = [backend.circuit_status(handle) for handle in handle_list]

status_list
# Out:
# [CircuitStatus(status=<StatusEnum.COMPLETED: 'Circuit has completed. Results are ready.'>, message='{"name": "Bell State Test", "submit-date": "2024-03-08T09:54:52.707575", "result-date": "2024-03-08T09:55:00.553796", "queue-position": null, "cost": "11.6", "error": null}', error_detail=None, completed_time=None, queued_time=None, submitted_time=None, running_time=None, cancelled_time=None, error_time=None, queue_position=None),
#  CircuitStatus(status=<StatusEnum.COMPLETED: 'Circuit has completed. Results are ready.'>, message='{"name": "Bell State Test", "submit-date": "2024-03-08T09:54:53.958565", "result-date": "2024-03-08T09:55:02.673716", "queue-position": null, "cost": "11.6", "error": null}', error_detail=None, completed_time=None, queued_time=None, submitted_time=None, running_time=None, cancelled_time=None, error_time=None, queue_position=None),
#  CircuitStatus(status=<StatusEnum.COMPLETED: 'Circuit has completed. Results are ready.'>, message='{"name": "Bell State Test", "submit-date": "2024-03-08T09:54:54.303784", "result-date": "2024-03-08T09:55:04.435361", "queue-position": null, "cost": "11.6", "error": null}', error_detail=None, completed_time=None, queued_time=None, submitted_time=None, running_time=None, cancelled_time=None, error_time=None, queue_position=None)]

# %% [markdown]
# Results for the batch submissions can be returned using `get_results`

# %%
result = backend.get_results(handle_list)

result
# Out:
# [BackendResult(q_bits={},c_bits={c[0]: 0, c[1]: 1},counts=None,shots=[[  0]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [192]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [ 64]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [ 64]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [192]
#   [192]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [ 64]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [192]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [192]
#   [192]
#   [192]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [192]
#   [192]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [ 64]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [192]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [192]
#   [192]
#   [192]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [ 64]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [128]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [192]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [192]],state=None,unitary=None,density_matrix=None),
#  BackendResult(q_bits={},c_bits={c[0]: 0, c[1]: 1},counts=None,shots=[[192]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [192]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [192]
#   [192]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [ 64]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [192]
#   [192]
#   [192]
#   [192]
#   [192]
#   [192]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [128]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [ 64]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [192]
#   [192]
#   [192]
#   [192]
#   [192]
#   [192]
#   [192]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [128]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [128]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [192]],state=None,unitary=None,density_matrix=None),
#  BackendResult(q_bits={},c_bits={c[0]: 0, c[1]: 1},counts=None,shots=[[  0]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [192]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [ 64]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [192]
#   [192]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [192]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [ 64]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [192]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [192]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [128]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [192]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [192]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [ 64]
#   [  0]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [  0]
#   [192]
#   [192]
#   [  0]
#   [  0]
#   [  0]
#   [192]],state=None,unitary=None,density_matrix=None)]

# %% [markdown]
# ## Parameterized Circuits

# %%
from pytket.circuit import fresh_symbol

# set up a parameterised circuit
a = fresh_symbol('a')
circuit = Circuit(3, name="Parameterised Circuit")
circuit.X(0) # Pauli-X gate
circuit.CX(0,1).CX(1,2) # CNOT gate 

circuit.Rz(a, 2) # Rotation-Z gate
circuit.CX(1,2).CX(0,1) # CNOT gate

render_circuit_jupyter(circuit)
# Out:
# <div style="resize: vertical; overflow: auto; height: 400px; display: block">
#     <iframe srcdoc="
# &lt;!DOCTYPE html&gt;
# &lt;html lang=&#34;en&#34;&gt;
# &lt;head&gt;
#     &lt;meta charset=&#34;UTF-8&#34;&gt;
#     &lt;!-- Download Vue 3--&gt;
# &lt;script type=&#34;application/javascript&#34; src=&#34;https://cdn.jsdelivr.net/npm/vue@3&#34;&gt;&lt;/script&gt;
# &lt;!-- Download Circuit Renderer with styles --&gt;
# &lt;script type=&#34;application/javascript&#34; src=&#34;https://unpkg.com/pytket-circuit-renderer@0.7/dist/pytket-circuit-renderer.umd.js&#34;&gt;&lt;/script&gt;
# &lt;link rel=&#34;stylesheet&#34; href=&#34;https://unpkg.com/pytket-circuit-renderer@0.7/dist/pytket-circuit-renderer.css&#34;&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#
#     &lt;div id=&#34;circuit-display-vue-container-4c3f515d-36fa-4688-b235-b014d2c778fd&#34; class=&#34;pytket-circuit-display-container&#34;&gt;
#         &lt;div style=&#34;display: none&#34;&gt;
#             &lt;div id=&#34;circuit-json-to-display&#34;&gt;{&#34;bits&#34;: [], &#34;commands&#34;: [{&#34;args&#34;: [[&#34;q&#34;, [0]]], &#34;op&#34;: {&#34;type&#34;: &#34;X&#34;}}, {&#34;args&#34;: [[&#34;q&#34;, [0]], [&#34;q&#34;, [1]]], &#34;op&#34;: {&#34;type&#34;: &#34;CX&#34;}}, {&#34;args&#34;: [[&#34;q&#34;, [1]], [&#34;q&#34;, [2]]], &#34;op&#34;: {&#34;type&#34;: &#34;CX&#34;}}, {&#34;args&#34;: [[&#34;q&#34;, [2]]], &#34;op&#34;: {&#34;params&#34;: [&#34;a&#34;], &#34;type&#34;: &#34;Rz&#34;}}, {&#34;args&#34;: [[&#34;q&#34;, [1]], [&#34;q&#34;, [2]]], &#34;op&#34;: {&#34;type&#34;: &#34;CX&#34;}}, {&#34;args&#34;: [[&#34;q&#34;, [0]], [&#34;q&#34;, [1]]], &#34;op&#34;: {&#34;type&#34;: &#34;CX&#34;}}], &#34;created_qubits&#34;: [], &#34;discarded_qubits&#34;: [], &#34;implicit_permutation&#34;: [[[&#34;q&#34;, [0]], [&#34;q&#34;, [0]]], [[&#34;q&#34;, [1]], [&#34;q&#34;, [1]]], [[&#34;q&#34;, [2]], [&#34;q&#34;, [2]]]], &#34;name&#34;: &#34;Parameterised Circuit&#34;, &#34;phase&#34;: &#34;0.0&#34;, &#34;qubits&#34;: [[&#34;q&#34;, [0]], [&#34;q&#34;, [1]], [&#34;q&#34;, [2]]]}&lt;/div&gt;
#         &lt;/div&gt;
#         &lt;circuit-display-container
#                 :circuit-element-str=&#34;&#39;#circuit-json-to-display&#39;&#34;
#                 :init-render-options=&#34;initRenderOptions&#34;
#         &gt;&lt;/circuit-display-container&gt;
#     &lt;/div&gt;
#     &lt;script type=&#34;application/javascript&#34;&gt;
#       const circuitRendererUid = &#34;4c3f515d-36fa-4688-b235-b014d2c778fd&#34;;
#       const displayOptions = JSON.parse(&#39;{}&#39;);
#
#       // Script to initialise the circuit renderer app
#
# const { createApp } = Vue;
# const circuitDisplayContainer = window[&#34;pytket-circuit-renderer&#34;].default;
# // Init variables to be shared between circuit display instances
# if (typeof window.pytketCircuitDisplays === &#34;undefined&#34;) {
#     window.pytketCircuitDisplays = {};
# }
# // Create the root Vue component
# const app = createApp({
#     delimiters: [&#39;[[#&#39;, &#39;#]]&#39;],
#     components: { circuitDisplayContainer },
#     data () {
#       return {
#         initRenderOptions: displayOptions,
#       }
#     }
# })
# app.config.unwrapInjectedRef = true;
# app.mount(&#34;#circuit-display-vue-container-&#34;+circuitRendererUid);
# window.pytketCircuitDisplays[circuitRendererUid] = app;
#     &lt;/script&gt;
#
#
#
# &lt;/body&gt;
# &lt;/html&gt;
# "
#             width="100%" height="100%"
#             style="border: none; outline: none; overflow: auto"></iframe>
# </div>

# %% [markdown]
# Now create a similar circuit, but with values of `a`

# %%
simulation_circuit = circuit.copy()
simulation_circuit.symbol_substitution({a: 0.5})
simulation_circuit.measure_all()

render_circuit_jupyter(simulation_circuit)
# Out:
# <div style="resize: vertical; overflow: auto; height: 400px; display: block">
#     <iframe srcdoc="
# &lt;!DOCTYPE html&gt;
# &lt;html lang=&#34;en&#34;&gt;
# &lt;head&gt;
#     &lt;meta charset=&#34;UTF-8&#34;&gt;
#     &lt;!-- Download Vue 3--&gt;
# &lt;script type=&#34;application/javascript&#34; src=&#34;https://cdn.jsdelivr.net/npm/vue@3&#34;&gt;&lt;/script&gt;
# &lt;!-- Download Circuit Renderer with styles --&gt;
# &lt;script type=&#34;application/javascript&#34; src=&#34;https://unpkg.com/pytket-circuit-renderer@0.7/dist/pytket-circuit-renderer.umd.js&#34;&gt;&lt;/script&gt;
# &lt;link rel=&#34;stylesheet&#34; href=&#34;https://unpkg.com/pytket-circuit-renderer@0.7/dist/pytket-circuit-renderer.css&#34;&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#
#     &lt;div id=&#34;circuit-display-vue-container-7c70c82c-0a6e-4f1a-b9aa-3fbd6303a561&#34; class=&#34;pytket-circuit-display-container&#34;&gt;
#         &lt;div style=&#34;display: none&#34;&gt;
#             &lt;div id=&#34;circuit-json-to-display&#34;&gt;{&#34;bits&#34;: [[&#34;c&#34;, [0]], [&#34;c&#34;, [1]], [&#34;c&#34;, [2]]], &#34;commands&#34;: [{&#34;args&#34;: [[&#34;q&#34;, [0]]], &#34;op&#34;: {&#34;type&#34;: &#34;X&#34;}}, {&#34;args&#34;: [[&#34;q&#34;, [0]], [&#34;q&#34;, [1]]], &#34;op&#34;: {&#34;type&#34;: &#34;CX&#34;}}, {&#34;args&#34;: [[&#34;q&#34;, [1]], [&#34;q&#34;, [2]]], &#34;op&#34;: {&#34;type&#34;: &#34;CX&#34;}}, {&#34;args&#34;: [[&#34;q&#34;, [2]]], &#34;op&#34;: {&#34;params&#34;: [&#34;0.5&#34;], &#34;type&#34;: &#34;Rz&#34;}}, {&#34;args&#34;: [[&#34;q&#34;, [1]], [&#34;q&#34;, [2]]], &#34;op&#34;: {&#34;type&#34;: &#34;CX&#34;}}, {&#34;args&#34;: [[&#34;q&#34;, [2]], [&#34;c&#34;, [2]]], &#34;op&#34;: {&#34;type&#34;: &#34;Measure&#34;}}, {&#34;args&#34;: [[&#34;q&#34;, [0]], [&#34;q&#34;, [1]]], &#34;op&#34;: {&#34;type&#34;: &#34;CX&#34;}}, {&#34;args&#34;: [[&#34;q&#34;, [0]], [&#34;c&#34;, [0]]], &#34;op&#34;: {&#34;type&#34;: &#34;Measure&#34;}}, {&#34;args&#34;: [[&#34;q&#34;, [1]], [&#34;c&#34;, [1]]], &#34;op&#34;: {&#34;type&#34;: &#34;Measure&#34;}}], &#34;created_qubits&#34;: [], &#34;discarded_qubits&#34;: [], &#34;implicit_permutation&#34;: [[[&#34;q&#34;, [0]], [&#34;q&#34;, [0]]], [[&#34;q&#34;, [1]], [&#34;q&#34;, [1]]], [[&#34;q&#34;, [2]], [&#34;q&#34;, [2]]]], &#34;name&#34;: &#34;Parameterised Circuit&#34;, &#34;phase&#34;: &#34;0.0&#34;, &#34;qubits&#34;: [[&#34;q&#34;, [0]], [&#34;q&#34;, [1]], [&#34;q&#34;, [2]]]}&lt;/div&gt;
#         &lt;/div&gt;
#         &lt;circuit-display-container
#                 :circuit-element-str=&#34;&#39;#circuit-json-to-display&#39;&#34;
#                 :init-render-options=&#34;initRenderOptions&#34;
#         &gt;&lt;/circuit-display-container&gt;
#     &lt;/div&gt;
#     &lt;script type=&#34;application/javascript&#34;&gt;
#       const circuitRendererUid = &#34;7c70c82c-0a6e-4f1a-b9aa-3fbd6303a561&#34;;
#       const displayOptions = JSON.parse(&#39;{}&#39;);
#
#       // Script to initialise the circuit renderer app
#
# const { createApp } = Vue;
# const circuitDisplayContainer = window[&#34;pytket-circuit-renderer&#34;].default;
# // Init variables to be shared between circuit display instances
# if (typeof window.pytketCircuitDisplays === &#34;undefined&#34;) {
#     window.pytketCircuitDisplays = {};
# }
# // Create the root Vue component
# const app = createApp({
#     delimiters: [&#39;[[#&#39;, &#39;#]]&#39;],
#     components: { circuitDisplayContainer },
#     data () {
#       return {
#         initRenderOptions: displayOptions,
#       }
#     }
# })
# app.config.unwrapInjectedRef = true;
# app.mount(&#34;#circuit-display-vue-container-&#34;+circuitRendererUid);
# window.pytketCircuitDisplays[circuitRendererUid] = app;
#     &lt;/script&gt;
#
#
#
# &lt;/body&gt;
# &lt;/html&gt;
# "
#             width="100%" height="100%"
#             style="border: none; outline: none; overflow: auto"></iframe>
# </div>

# %%
compiled_circuit = backend.get_compiled_circuit(simulation_circuit,optimisation_level=2)
render_circuit_jupyter(compiled_circuit)
# Out:
# <div style="resize: vertical; overflow: auto; height: 400px; display: block">
#     <iframe srcdoc="
# &lt;!DOCTYPE html&gt;
# &lt;html lang=&#34;en&#34;&gt;
# &lt;head&gt;
#     &lt;meta charset=&#34;UTF-8&#34;&gt;
#     &lt;!-- Download Vue 3--&gt;
# &lt;script type=&#34;application/javascript&#34; src=&#34;https://cdn.jsdelivr.net/npm/vue@3&#34;&gt;&lt;/script&gt;
# &lt;!-- Download Circuit Renderer with styles --&gt;
# &lt;script type=&#34;application/javascript&#34; src=&#34;https://unpkg.com/pytket-circuit-renderer@0.7/dist/pytket-circuit-renderer.umd.js&#34;&gt;&lt;/script&gt;
# &lt;link rel=&#34;stylesheet&#34; href=&#34;https://unpkg.com/pytket-circuit-renderer@0.7/dist/pytket-circuit-renderer.css&#34;&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#
#     &lt;div id=&#34;circuit-display-vue-container-bfe9d707-86d4-40a7-bfbe-2f64939b5aec&#34; class=&#34;pytket-circuit-display-container&#34;&gt;
#         &lt;div style=&#34;display: none&#34;&gt;
#             &lt;div id=&#34;circuit-json-to-display&#34;&gt;{&#34;bits&#34;: [[&#34;c&#34;, [0]], [&#34;c&#34;, [1]], [&#34;c&#34;, [2]]], &#34;commands&#34;: [{&#34;args&#34;: [[&#34;q&#34;, [0]]], &#34;op&#34;: {&#34;params&#34;: [&#34;1&#34;, &#34;-3&#34;], &#34;type&#34;: &#34;PhasedX&#34;}}, {&#34;args&#34;: [[&#34;q&#34;, [1]]], &#34;op&#34;: {&#34;params&#34;: [&#34;0.5&#34;, &#34;-1.5&#34;], &#34;type&#34;: &#34;PhasedX&#34;}}, {&#34;args&#34;: [[&#34;q&#34;, [2]]], &#34;op&#34;: {&#34;params&#34;: [&#34;1&#34;, &#34;-5/2&#34;], &#34;type&#34;: &#34;PhasedX&#34;}}, {&#34;args&#34;: [[&#34;q&#34;, [0]], [&#34;q&#34;, [1]]], &#34;op&#34;: {&#34;params&#34;: [&#34;0.5&#34;], &#34;type&#34;: &#34;ZZPhase&#34;}}, {&#34;args&#34;: [[&#34;q&#34;, [1]]], &#34;op&#34;: {&#34;params&#34;: [&#34;5/2&#34;, &#34;0&#34;], &#34;type&#34;: &#34;PhasedX&#34;}}, {&#34;args&#34;: [[&#34;q&#34;, [1]], [&#34;q&#34;, [2]]], &#34;op&#34;: {&#34;params&#34;: [&#34;0.5&#34;], &#34;type&#34;: &#34;ZZPhase&#34;}}, {&#34;args&#34;: [[&#34;q&#34;, [1]]], &#34;op&#34;: {&#34;params&#34;: [&#34;-1.5&#34;, &#34;0&#34;], &#34;type&#34;: &#34;PhasedX&#34;}}, {&#34;args&#34;: [[&#34;q&#34;, [2]]], &#34;op&#34;: {&#34;params&#34;: [&#34;1&#34;, &#34;-3&#34;], &#34;type&#34;: &#34;PhasedX&#34;}}, {&#34;args&#34;: [[&#34;q&#34;, [2]], [&#34;c&#34;, [2]]], &#34;op&#34;: {&#34;type&#34;: &#34;Measure&#34;}}, {&#34;args&#34;: [[&#34;q&#34;, [0]], [&#34;q&#34;, [1]]], &#34;op&#34;: {&#34;params&#34;: [&#34;0.5&#34;], &#34;type&#34;: &#34;ZZPhase&#34;}}, {&#34;args&#34;: [[&#34;q&#34;, [0]], [&#34;c&#34;, [0]]], &#34;op&#34;: {&#34;type&#34;: &#34;Measure&#34;}}, {&#34;args&#34;: [[&#34;q&#34;, [1]]], &#34;op&#34;: {&#34;params&#34;: [&#34;1/2&#34;, &#34;-1/2&#34;], &#34;type&#34;: &#34;PhasedX&#34;}}, {&#34;args&#34;: [[&#34;q&#34;, [1]], [&#34;c&#34;, [1]]], &#34;op&#34;: {&#34;type&#34;: &#34;Measure&#34;}}], &#34;created_qubits&#34;: [], &#34;discarded_qubits&#34;: [], &#34;implicit_permutation&#34;: [[[&#34;q&#34;, [0]], [&#34;q&#34;, [0]]], [[&#34;q&#34;, [1]], [&#34;q&#34;, [1]]], [[&#34;q&#34;, [2]], [&#34;q&#34;, [2]]]], &#34;name&#34;: &#34;Parameterised Circuit&#34;, &#34;phase&#34;: &#34;1.5&#34;, &#34;qubits&#34;: [[&#34;q&#34;, [0]], [&#34;q&#34;, [1]], [&#34;q&#34;, [2]]]}&lt;/div&gt;
#         &lt;/div&gt;
#         &lt;circuit-display-container
#                 :circuit-element-str=&#34;&#39;#circuit-json-to-display&#39;&#34;
#                 :init-render-options=&#34;initRenderOptions&#34;
#         &gt;&lt;/circuit-display-container&gt;
#     &lt;/div&gt;
#     &lt;script type=&#34;application/javascript&#34;&gt;
#       const circuitRendererUid = &#34;bfe9d707-86d4-40a7-bfbe-2f64939b5aec&#34;;
#       const displayOptions = JSON.parse(&#39;{}&#39;);
#
#       // Script to initialise the circuit renderer app
#
# const { createApp } = Vue;
# const circuitDisplayContainer = window[&#34;pytket-circuit-renderer&#34;].default;
# // Init variables to be shared between circuit display instances
# if (typeof window.pytketCircuitDisplays === &#34;undefined&#34;) {
#     window.pytketCircuitDisplays = {};
# }
# // Create the root Vue component
# const app = createApp({
#     delimiters: [&#39;[[#&#39;, &#39;#]]&#39;],
#     components: { circuitDisplayContainer },
#     data () {
#       return {
#         initRenderOptions: displayOptions,
#       }
#     }
# })
# app.config.unwrapInjectedRef = true;
# app.mount(&#34;#circuit-display-vue-container-&#34;+circuitRendererUid);
# window.pytketCircuitDisplays[circuitRendererUid] = app;
#     &lt;/script&gt;
#
#
#
# &lt;/body&gt;
# &lt;/html&gt;
# "
#             width="100%" height="100%"
#             style="border: none; outline: none; overflow: auto"></iframe>
# </div>

# %%
n_shots = 1000
backend.cost(compiled_circuit, n_shots=n_shots, syntax_checker='H1-1SC')
# Out:
# 18.4

# %%
handle = backend.process_circuit(compiled_circuit, n_shots=n_shots)

# %%
status = backend.circuit_status(handle)
print(status)
# Out:
# CircuitStatus(status=<StatusEnum.COMPLETED: 'Circuit has completed. Results are ready.'>, message='{"name": "Parameterised Circuit", "submit-date": "2024-03-08T09:56:25.088009", "result-date": "2024-03-08T09:56:27.854289", "queue-position": null, "cost": "18.4", "error": null}', error_detail=None, completed_time=None, queued_time=None, submitted_time=None, running_time=None, cancelled_time=None, error_time=None, queue_position=None)

# %%
result = backend.get_result(handle)
result
# Out:
# BackendResult(q_bits={},c_bits={c[0]: 0, c[1]: 1, c[2]: 2},counts=None,shots=[[128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [  0]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [  0]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [  0]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [  0]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]
#  [128]],state=None,unitary=None,density_matrix=None)

# %% [markdown]
# ## Conditional Gates

# %%
from pytket.circuit import Circuit, if_bit

# create a circuit with a classical control

circ = Circuit(name="Conditional Gate")
qreg = circ.add_q_register("q", 3)
creg = circ.add_c_register("c", 2)


circ.X(qreg[0]).H(qreg[0])

# prepare a bell state on qubits 1 and 2
circ.H(qreg[1])
circ.CX(qreg[1], qreg[2])

# construct the teleportatin protocol
circ.CX(qreg[0], qreg[1])
circ.H(qreg[0])
circ.Measure(qreg[0], creg[0])
circ.Measure(qreg[1], creg[1])


# if (creg[1] == 1)
circ.X(qreg[2], condition = if_bit(creg[1]))

# if (creg[0] == 1)
circ.Z(qreg[2], condition = if_bit(creg[0]))

render_circuit_jupyter(circ)
# Out:
# <div style="resize: vertical; overflow: auto; height: 400px; display: block">
#     <iframe srcdoc="
# &lt;!DOCTYPE html&gt;
# &lt;html lang=&#34;en&#34;&gt;
# &lt;head&gt;
#     &lt;meta charset=&#34;UTF-8&#34;&gt;
#     &lt;!-- Download Vue 3--&gt;
# &lt;script type=&#34;application/javascript&#34; src=&#34;https://cdn.jsdelivr.net/npm/vue@3&#34;&gt;&lt;/script&gt;
# &lt;!-- Download Circuit Renderer with styles --&gt;
# &lt;script type=&#34;application/javascript&#34; src=&#34;https://unpkg.com/pytket-circuit-renderer@0.7/dist/pytket-circuit-renderer.umd.js&#34;&gt;&lt;/script&gt;
# &lt;link rel=&#34;stylesheet&#34; href=&#34;https://unpkg.com/pytket-circuit-renderer@0.7/dist/pytket-circuit-renderer.css&#34;&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#
#     &lt;div id=&#34;circuit-display-vue-container-a7096a62-f24c-4887-8bf0-4b137137a150&#34; class=&#34;pytket-circuit-display-container&#34;&gt;
#         &lt;div style=&#34;display: none&#34;&gt;
#             &lt;div id=&#34;circuit-json-to-display&#34;&gt;{&#34;bits&#34;: [[&#34;c&#34;, [0]], [&#34;c&#34;, [1]]], &#34;commands&#34;: [{&#34;args&#34;: [[&#34;q&#34;, [0]]], &#34;op&#34;: {&#34;type&#34;: &#34;X&#34;}}, {&#34;args&#34;: [[&#34;q&#34;, [1]]], &#34;op&#34;: {&#34;type&#34;: &#34;H&#34;}}, {&#34;args&#34;: [[&#34;q&#34;, [0]]], &#34;op&#34;: {&#34;type&#34;: &#34;H&#34;}}, {&#34;args&#34;: [[&#34;q&#34;, [1]], [&#34;q&#34;, [2]]], &#34;op&#34;: {&#34;type&#34;: &#34;CX&#34;}}, {&#34;args&#34;: [[&#34;q&#34;, [0]], [&#34;q&#34;, [1]]], &#34;op&#34;: {&#34;type&#34;: &#34;CX&#34;}}, {&#34;args&#34;: [[&#34;q&#34;, [1]], [&#34;c&#34;, [1]]], &#34;op&#34;: {&#34;type&#34;: &#34;Measure&#34;}}, {&#34;args&#34;: [[&#34;q&#34;, [0]]], &#34;op&#34;: {&#34;type&#34;: &#34;H&#34;}}, {&#34;args&#34;: [[&#34;q&#34;, [0]], [&#34;c&#34;, [0]]], &#34;op&#34;: {&#34;type&#34;: &#34;Measure&#34;}}, {&#34;args&#34;: [[&#34;c&#34;, [1]], [&#34;q&#34;, [2]]], &#34;op&#34;: {&#34;conditional&#34;: {&#34;op&#34;: {&#34;type&#34;: &#34;X&#34;}, &#34;value&#34;: 1, &#34;width&#34;: 1}, &#34;type&#34;: &#34;Conditional&#34;}}, {&#34;args&#34;: [[&#34;c&#34;, [0]], [&#34;q&#34;, [2]]], &#34;op&#34;: {&#34;conditional&#34;: {&#34;op&#34;: {&#34;type&#34;: &#34;Z&#34;}, &#34;value&#34;: 1, &#34;width&#34;: 1}, &#34;type&#34;: &#34;Conditional&#34;}}], &#34;created_qubits&#34;: [], &#34;discarded_qubits&#34;: [], &#34;implicit_permutation&#34;: [[[&#34;q&#34;, [0]], [&#34;q&#34;, [0]]], [[&#34;q&#34;, [1]], [&#34;q&#34;, [1]]], [[&#34;q&#34;, [2]], [&#34;q&#34;, [2]]]], &#34;name&#34;: &#34;Conditional Gate&#34;, &#34;phase&#34;: &#34;0.0&#34;, &#34;qubits&#34;: [[&#34;q&#34;, [0]], [&#34;q&#34;, [1]], [&#34;q&#34;, [2]]]}&lt;/div&gt;
#         &lt;/div&gt;
#         &lt;circuit-display-container
#                 :circuit-element-str=&#34;&#39;#circuit-json-to-display&#39;&#34;
#                 :init-render-options=&#34;initRenderOptions&#34;
#         &gt;&lt;/circuit-display-container&gt;
#     &lt;/div&gt;
#     &lt;script type=&#34;application/javascript&#34;&gt;
#       const circuitRendererUid = &#34;a7096a62-f24c-4887-8bf0-4b137137a150&#34;;
#       const displayOptions = JSON.parse(&#39;{}&#39;);
#
#       // Script to initialise the circuit renderer app
#
# const { createApp } = Vue;
# const circuitDisplayContainer = window[&#34;pytket-circuit-renderer&#34;].default;
# // Init variables to be shared between circuit display instances
# if (typeof window.pytketCircuitDisplays === &#34;undefined&#34;) {
#     window.pytketCircuitDisplays = {};
# }
# // Create the root Vue component
# const app = createApp({
#     delimiters: [&#39;[[#&#39;, &#39;#]]&#39;],
#     components: { circuitDisplayContainer },
#     data () {
#       return {
#         initRenderOptions: displayOptions,
#       }
#     }
# })
# app.config.unwrapInjectedRef = true;
# app.mount(&#34;#circuit-display-vue-container-&#34;+circuitRendererUid);
# window.pytketCircuitDisplays[circuitRendererUid] = app;
#     &lt;/script&gt;
#
#
#
# &lt;/body&gt;
# &lt;/html&gt;
# "
#             width="100%" height="100%"
#             style="border: none; outline: none; overflow: auto"></iframe>
# </div>
